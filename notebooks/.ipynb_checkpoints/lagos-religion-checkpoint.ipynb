# %% [markdown]
# # Folium Lagos Healthcare Demo

# %%
import folium
import json
from branca.element import Template, MacroElement

# %%
def read_geojson(file):
    with open(file) as f:
        geojson = json.load(f)
    return geojson["features"]

healthcare = read_geojson("../data/geojson/health/health-care-facilities-primary-secondary-and-tertiary.geojson")
labs = read_geojson("../data/geojson/health/laboratories.geojson")
pharmaceuticals = read_geojson("../data/geojson/health/pharmaceutical-facilities.geojson")

healthcare[0]
# Out:
# {'type': 'Feature',
#  'id': 'sv_fc_healthcare_facilities.fid--3786de59_17053f1df13_-6d10',
#  'geometry': {'type': 'Point', 'coordinates': [3.3198, 6.625]},
#  'geometry_name': 'geometry_type',
#  'properties': {'latitude': 6.624976667,
#   'longitude': 3.319815,
#   'contact_phone': None,
#   'contact_name': None,
#   'ri_service_status': 'Yes',
#   'timestamp': '2018-11-22T12:59:56Z',
#   'cce_quantity': None,
#   'cce_available': 'Unknown',
#   'cce_lastupdated': None,
#   'category': 'Private Clinic',
#   'global_id': 'cb468dde-a771-49ae-90db-06841012f6ad',
#   'name': 'Adu Medical Clinic',
#   'alternate_name': None,
#   'functional_status': 'Functional',
#   'type': 'Primary',
#   'ownership': 'Private',
#   'ward_code': 'LASAGG01',
#   'accessibility': None,
#   'source': 'GRID',
#   'ward_name': 'Atobaje',
#   'lga_code': '25001',
#   'lga_name': 'Agege',
#   'state_code': 'LA',
#   'state_name': 'Lagos'}}

# %%
lagos_map = folium.Map(
    location=[6.5421, 3.5079],
    tiles="cartodbpositron",
    zoom_start=10
)

for point in healthcare:
    folium.Circle(
        location=point["geometry"]["coordinates"][::-1],
        radius=2,
        popup=point["properties"]["name"],
        color='#ff0000',
        fill=True,
        fill_color='#ff0000'
    ).add_to(lagos_map)
    
for point in pharmaceuticals:
    folium.Circle(
        location=point["geometry"]["coordinates"][::-1],
        radius=2,
        popup=point["properties"]["name"],
        color='#0000ff',
        fill=True,
        fill_color='#0000ff'
    ).add_to(lagos_map)
    
for point in labs:
    folium.Circle(
        location=point["geometry"]["coordinates"][::-1],
        radius=2,
        popup=point["properties"]["name"],
        color='#00ff00',
        fill=True,
        fill_color='#00ff00'
    ).add_to(lagos_map)

template = """
{% macro html(this, kwargs) %}

<!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>jQuery UI Draggable - Default functionality</title>
  <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

  <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
  <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
  
  <script>
  $( function() {
    $( "#maplegend" ).draggable({
                    start: function (event, ui) {
                        $(this).css({
                            right: "auto",
                            top: "auto",
                            bottom: "auto"
                        });
                    }
                });
});

  </script>
</head>
<body>

 
<div id='maplegend' class='maplegend' 
    style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
     border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 80px;'>
     
<div class='legend-scale'>
  <ul class='legend-labels'>
    <li><span style='background:green;opacity:0.7;'></span>Laboratories</li>
    <li><span style='background:red;opacity:0.7;'></span>Healthcare Services</li>
    <li><span style='background:blue;opacity:0.7;'></span>Pharmaceuticals</li>
  </ul>
</div>
</div>
 
</body>
</html>

<style type='text/css'>
  .maplegend .legend-title {
    text-align: left;
    margin-bottom: 5px;
    font-weight: bold;
    font-size: 90%;
    }
  .maplegend .legend-scale ul {
    margin: 0;
    margin-bottom: 5px;
    padding: 0;
    float: left;
    list-style: none;
    }
  .maplegend .legend-scale ul li {
    font-size: 80%;
    list-style: none;
    margin-left: 0;
    line-height: 18px;
    margin-bottom: 2px;
    }
  .maplegend ul.legend-labels li span {
    display: block;
    float: left;
    height: 16px;
    width: 30px;
    margin-right: 5px;
    margin-left: 0;
    border: 1px solid #999;
    }
  .maplegend .legend-source {
    font-size: 80%;
    color: #777;
    clear: both;
    }
  .maplegend a {
    color: #777;
    }
</style>
{% endmacro %}"""

macro = MacroElement()
macro._template = Template(template)

folium.LayerControl().add_to(lagos_map)
lagos_map.get_root().add_child(macro)

lagos_map.save("outputs/lagos_health.html")
lagos_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
