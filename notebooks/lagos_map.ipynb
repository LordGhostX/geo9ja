# %% [markdown]
# # Folium Lagos Demo

# %%
import folium
import pandas as pd

# %%
# reading population data
population_data = pd.read_csv("../data/datasets/lagos_lga_population.csv", usecols=["local", "mean"])
population_data.head()
# Out:
#       local          mean
# 0     agege  2.894498e+05
# 1   ajeromi  3.142226e+05
# 2  alimosho  2.079944e+06
# 3    odofin  3.775413e+05
# 4     apapa  2.713695e+05

# %%
lagos_map = folium.Map(
    location=[6.5244, 3.3792],
    tiles="Stamen Toner",
    zoom_start=9
)

my_map = "../data/geojson/maps/lagos_lga.geojson"
folium.Choropleth(
    geo_data=my_map,
    name='choropleth',
    data=population_data,
    columns=['local', 'mean'],
    fill_color='YlGn',
    key_on='feature.properties.NAME_2',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='LGA Population Count'
).add_to(lagos_map)

folium.LayerControl().add_to(lagos_map)

lagos_map.save("outputs/lagos_lga.html")
lagos_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
